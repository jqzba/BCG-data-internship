# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %matplotlib inline

sns.set(color_codes=True)

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dc85420e-f421-4f5e-b086-9c36c9e8e5f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc85420e-f421-4f5e-b086-9c36c9e8e5f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
client_df = pd.read_csv('client_data.csv')
price_df = pd.read_csv('price_data.csv')

# %%
client_df.head(5)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
# 3      1584             0                0  2010-03-30  2016-03-30
# 4      4425             0              526  2010-01-13  2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
price_df.head()
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
# 3  038af19179925da21a25619c5a24b745  2015-04-01            0.149626
# 4  038af19179925da21a25619c5a24b745  2015-05-01            0.149626
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
# 3             0.0                 0.0           44.266931             0.0
# 4             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0
# ...

# %%
client_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  object
#  6   date_end                        14606 non-null  object
#  7   date_modif_prod                 14606 non-null  object
#  8   date_renewal                    14606 non-null  object
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
# ...

# %% [markdown]
# Statistics about the dataset

# %%
client_df.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# std           3247.786255                  5.108289                66.165783
# ...

# %%
price_df.describe()
# Out:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# 25%             40.728885        0.000000            0.000000
# ...

# %%
#check duplicates 

dublicates_client = client_df[client_df.duplicated(keep=False)]
print(dublicates_client)

dublicates_price = price_df[price_df.duplicated(keep=False)]
dublicates_price.head()
# Out:
# Empty DataFrame
# Columns: [id, channel_sales, cons_12m, cons_gas_12m, cons_last_month, date_activ, date_end, date_modif_prod, date_renewal, forecast_cons_12m, forecast_cons_year, forecast_discount_energy, forecast_meter_rent_12m, forecast_price_energy_off_peak, forecast_price_energy_peak, forecast_price_pow_off_peak, has_gas, imp_cons, margin_gross_pow_ele, margin_net_pow_ele, nb_prod_act, net_margin, num_years_antig, origin_up, pow_max, churn, contract_start_year, cortract_end_year]
# Index: []
#
# [0 rows x 28 columns]
# Empty DataFrame
# Columns: [id, price_date, price_off_peak_var, price_peak_var, price_mid_peak_var, price_off_peak_fix, price_peak_fix, price_mid_peak_fix]
# Index: []

# %%
#check null values from dataframe

print(price_df.isnull().sum())

print(client_df.isnull().sum())
# Out:
# id                    0
# price_date            0
# price_off_peak_var    0
# price_peak_var        0
# price_mid_peak_var    0
# price_off_peak_fix    0
# price_peak_fix        0
# price_mid_peak_fix    0
# dtype: int64
# id                                0
# channel_sales                     0
# cons_12m                          0
# cons_gas_12m                      0
# cons_last_month                   0
# date_activ                        0
# date_end                          0
# date_modif_prod                   0
# date_renewal                      0
# forecast_cons_12m                 0
# forecast_cons_year                0
# forecast_discount_energy          0
# forecast_meter_rent_12m           0
# forecast_price_energy_off_peak    0
# forecast_price_energy_peak        0
# forecast_price_pow_off_peak       0
# has_gas                           0
# imp_cons                          0
# margin_gross_pow_ele              0
# margin_net_pow_ele                0
# ...

# %% [markdown]
# There are none 0 values

# %%
#convert datetime features to right datatype

for f in ['date_activ', 'date_end', 'date_modif_prod', 'date_renewal']:
  client_df[f] = pd.to_datetime(client_df[f])

# %%
#add year feature to dataframe
client_df['contract_start_year'] = client_df['date_activ'].dt.year
client_df['cortract_end_year'] = client_df['date_end'].dt.year

# %%
print(client_df.head())
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month date_activ   date_end  \
# 0         0         54946                0 2013-06-15 2016-06-15
# 1      4660             0                0 2009-08-21 2016-08-30
# 2       544             0                0 2010-04-16 2016-04-16
# 3      1584             0                0 2010-03-30 2016-03-30
# 4      4425             0              526 2010-01-13 2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  margin_gross_pow_ele  \
# ...

# %%
def describe_catergorical(data):
  cat_columns = data.dtypes[data.dtypes == 'object'].index.tolist()
  if len(cat_columns) != 0:
    print('Categorical variables are', cat_columns, '\n' + '==' * 30)

    for cat in cat_columns:
        describe_frame = data[[cat]].value_counts().reset_index(name='count')
        describe_frame['proportion'] = describe_frame['count']/len(data)
        print(describe_frame, '\n' + '--'*40)

  else:
    print('No categorical variables')

# %%
describe_catergorical(data=client_df)
# Out:
# Categorical variables are ['id', 'channel_sales', 'has_gas', 'origin_up']
# ...
#                                      id  count  proportion
# 0      0002203ffbb812588b632b9e628cc38d      1    0.000068
# 1      ab250252dfaded1c9a54834f9c829b43      1    0.000068
# 2      ab32c3a8d93c88b485499566526cb34d      1    0.000068
# 3      ab3392ec2bfd3605624f31d3c6828c21      1    0.000068
# 4      ab346731fef5aa291919ea43e45af5a7      1    0.000068
# ...                                 ...    ...         ...
# 14601  55091aace7bd0fadd194f46cb4886fea      1    0.000068
# 14602  550b8d2f9c298abd8f05fca3bc1a13c4      1    0.000068
# 14603  5514b18508f378a39f41657554aa72e3      1    0.000068
# 14604  551cb1b1faf72259c2c182dedec12c98      1    0.000068
# 14605  ffff7fa066f1fb305ae285bb03bf325a      1    0.000068
#
# [14606 rows x 3 columns]
# --------------------------------------------------------------------------------
#                       channel_sales  count  proportion
# ...

# %% [markdown]
# "channel sales" and "origin_up" are not understandable, so I make them numeric data type by label encoding

# %%
from sklearn.preprocessing import LabelEncoder

channel_encoder = LabelEncoder()

client_df['channel_sales'] = channel_encoder.fit_transform(client_df['channel_sales'])

origin_encoder = LabelEncoder()

client_df['origin_up'] = origin_encoder.fit_transform(client_df['origin_up'])

# %%
def plot_stacked_bars(dataframe, title_, size_=(18, 10), rot_=0, legend_="upper right"):
    """
    Plot stacked bars with annotations
    """
    ax = dataframe.plot(
        kind="bar",
        stacked=True,
        figsize=size_,
        rot=rot_,
        title=title_
    )

    # Annotate bars
    annotate_stacked_bars(ax, textsize=14)
    # Rename legend
    plt.legend(["Retention", "Churn"], loc=legend_)
    # Labels
    plt.ylabel("Company base (%)")
    plt.show()

def annotate_stacked_bars(ax, pad=0.99, colour="white", textsize=13):
    """
    Add value annotations to the bars
    """

    # Iterate over the plotted rectanges/bars
    for p in ax.patches:
        
        # Calculate annotation
        value = str(round(p.get_height(),1))
        # If value is 0 do not annotate
        if value == '0.0':
            continue
        ax.annotate(
            value,
            ((p.get_x()+ p.get_width()/2)*pad-0.05, (p.get_y()+p.get_height()/2)*pad),
            color=colour,
            size=textsize
        )

def plot_distribution(dataframe, column, ax, bins_=50):
    """
    Plot variable distirbution in a stacked histogram of churned or retained company
    """
    # Create a temporal dataframe with the data to be plot
    temp = pd.DataFrame({"Retention": dataframe[dataframe["churn"]==0][column],
    "Churn":dataframe[dataframe["churn"]==1][column]})
    # Plot the histogram
    temp[["Retention","Churn"]].plot(kind='hist', bins=bins_, ax=ax, stacked=True)
    # X-axis label
    ax.set_xlabel(column)
    # Change the x-axis to plain style
    ax.ticklabel_format(style='plain', axis='x')

# %%
churn = client_df[['id', 'churn']]
print(churn.head())
churn.columns = ['Companies', 'churn']
#counts the values of churn and not churn companies
churn_total = churn.groupby(churn['churn']).count()
print(churn_total)

churn_percentage = churn_total / churn_total.sum() * 100
print(churn_percentage)

plot_stacked_bars(churn_percentage.transpose(), "Churning status", (5, 5))
# Out:
#                                  id  churn
# 0  24011ae4ebbe3035111d65fa7c15bc57      1
# 1  d29c2c54acc38ff3c0614d0a653813dd      0
# 2  764c75f661154dac3a6c254cd082ea7d      0
# 3  bba03439a292a1e166f80264c16191cb      0
# 4  149d57cf92fc41cf94415803a877cb4b      0
#        Companies
# churn
# 0          13187
# 1           1419
#        Companies
# churn
# 0      90.284814
# 1       9.715186

# %%
#let make function that plots feature distribution for features

def plot_bar_chart_with_percent(df, target_variable, if_sort=False, gap_label_bar=0.01, 
                         fig_size = (9,6)):
  plot_data = client_df[[target_variable]].value_counts().reset_index(name='count')
  plot_data['percent'] = plot_data['count']/plot_data['count'].sum()

  if if_sort:
    x_order = plot_data.sort_values(by=['percent'], ascending=False)[target_variable]
  else:
    x_order = plot_data.sort_values(by=[target_variable], ascending=True)[target_variable]

  fig = plt.figure(figsize = fig_size)
  ax = sns.barplot(data = plot_data, x=target_variable, y='percent', order = x_order)

  #add label
  for p in ax.patches:
    x = p.get_x() + p.get_width()/2
    y = p.get_height() + gap_label_bar
    ax.annotate(s='{:.1f}%'.format(p.get_height()*100), xy=(x, y), ha='center')

  ax.margins(y=0.1)

# %%
#function that plot stacked bars for different classes
def plot_stacked_bar_by_churn(df, target_variable, figsize=(9, 6)):
  plot_data = df.groupby([target_variable, 'churn']).size().reset_index(name='count')
  plot_data = plot_data.pivot(index=target_variable, columns='churn', 
                              values='count').fillna(0)
  print(plot_data)
  plot_data = plot_data.div(plot_data.sum(axis=1), axis=0)
  

  ax = plot_data.plot(kind='bar', rot=False, stacked=True, figsize = figsize)
  plt.legend(['stay', 'switch'], loc='upper right', ncol=2)

  #add labels
  for p in ax.patches:
    percentage = '{:.1f}%'.format(p.get_height()*100)

    if percentage != '0.0%':
      x = p.get_x() + p.get_width()/2
      y = 1 - p.get_height()/1.8
      ax.annotate(s=percentage, xy=(x,y), ha='center')

  ax.margins(y=0.1)

# %%
plot_bar_chart_with_percent(df=client_df, target_variable='channel_sales',
                            gap_label_bar=0.02)

# %% [markdown]
# Type 4 is the most commo sales channel, 1, 3, 6 are very rare

# %%
plot_bar_chart_with_percent(df=client_df, target_variable='origin_up', if_sort=True)

# %%
plot_stacked_bar_by_churn(df=client_df, target_variable='channel_sales')
# Out:
# churn               0      1
# channel_sales
# 0              3442.0  283.0
# 1                 3.0    0.0
# 2               818.0   75.0
# 3                 2.0    0.0
# 4              5934.0  820.0
# 5              1740.0  103.0
# 6                11.0    0.0
# 7              1237.0  138.0

# %% [markdown]
# Churn rate differs from 5.6% to 12.1% depending to sales channel what have used.

# %%
plot_stacked_bar_by_churn(df=client_df, target_variable='origin_up')
# Out:
# churn           0      1
# origin_up
# 0            60.0    4.0
# 1             1.0    0.0
# 2          4036.0  258.0
# 3          2884.0  264.0
# 4          6204.0  893.0
# 5             2.0    0.0

# %% [markdown]
# origin_up = code of the electricity campaign the customer first subscribed to
# 1 and 5 campaing have very few customers, on the more often used channels
# churn rate differ from 6% to 12.6%

# %%
plot_bar_chart_with_percent(df=client_df, target_variable='contract_start_year', 
                            gap_label_bar=0.005, fig_size=(12, 6))
plot_stacked_bar_by_churn(df=client_df, target_variable='contract_start_year', 
                          figsize=(15, 6))
# Out:
# churn                     0      1
# contract_start_year
# 2003                   35.0    4.0
# 2004                  125.0   12.0
# 2005                  179.0   10.0
# 2006                   34.0    2.0
# 2007                   93.0    2.0
# 2008                  118.0    6.0
# 2009                 2481.0  209.0
# 2010                 3350.0  259.0
# 2011                 2486.0  272.0
# 2012                 3248.0  456.0
# 2013                 1037.0  187.0
# 2014                    1.0    0.0

# %% [markdown]
# Most of the customers have joined after 2009.
# Among these customers it looks like newers are more likely to change the company.

# %%
plot_bar_chart_with_percent(df=client_df, target_variable='num_years_antig', 
                            fig_size= (15, 6))
plot_stacked_bar_by_churn(df=client_df, target_variable='num_years_antig', 
                          figsize=(15, 6))
# Out:
# churn                 0      1
# num_years_antig
# 1                   1.0    0.0
# 2                   8.0    3.0
# 3                2104.0  329.0
# 4                3510.0  472.0
# 5                2117.0  200.0
# 6                4430.0  339.0
# 7                 467.0   42.0
# 8                  98.0    5.0
# 9                  91.0    1.0
# 10                 77.0    4.0
# 11                173.0   12.0
# 12                 99.0   11.0
# 13                 12.0    1.0

# %% [markdown]
# Most contractors are 3-6 years and most churn is happening on second year. With these information, we can conclude that most of the churn will probalbly happen after the first discount will end.

# %%
consumption = client_df[['id', 'cons_12m', 'cons_gas_12m', 'cons_last_month', 'imp_cons', 'has_gas', 'churn']]

fig, axs = plt.subplots(nrows=1, figsize=(18, 5))

plot_distribution(consumption, 'cons_last_month', axs)

# %%
#calculate correlations with churn

corr = client_df.corr()[['churn']]
sns.heatmap(corr, annot=True)

# %%
price_df.head()
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
# 3  038af19179925da21a25619c5a24b745  2015-04-01            0.149626
# 4  038af19179925da21a25619c5a24b745  2015-05-01            0.149626
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
# 3             0.0                 0.0           44.266931             0.0
# 4             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0
# ...

# %%
price = price_df.drop(['price_date'], axis=1)
print(price.head())
# Out:
#                                  id  price_off_peak_var  price_peak_var  \
# 0  038af19179925da21a25619c5a24b745            0.151367             0.0
# 1  038af19179925da21a25619c5a24b745            0.151367             0.0
# 2  038af19179925da21a25619c5a24b745            0.151367             0.0
# 3  038af19179925da21a25619c5a24b745            0.149626             0.0
# 4  038af19179925da21a25619c5a24b745            0.149626             0.0
#
#    price_mid_peak_var  price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# 0                 0.0           44.266931             0.0                 0.0
# 1                 0.0           44.266931             0.0                 0.0
# 2                 0.0           44.266931             0.0                 0.0
# 3                 0.0           44.266931             0.0                 0.0
# 4                 0.0           44.266931             0.0                 0.0

# %%
price.describe()
# Out:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# 25%             40.728885        0.000000            0.000000
# ...

# %%
price.hist(bins=25, figsize=(20, 15))
plt.show()

# %% [markdown]
# We can see from distributions, that in off peak prices are normally distributed, but on peaks there are lot of companies that are not using electricity. That would be a sign that their customers are price sensitive, what we will explore next.

# %% [markdown]
# **Sub-Task 2**:
#
# Verify the hypothesis of price sensitivity being to some extent correlated with churn. It is up to you to define price sensitivity and calculate it. You should spend around 30 minutes on this.

# %%
price_stat = price.groupby(['id'])
print(price_stat.head())

#lets make mix min and mean values for company prices in different price periods
stat = ['max', 'min', 'mean']
price_stat = price_stat.agg({'price_off_peak_var': stat, 'price_off_peak_fix': stat, 
                             'price_mid_peak_var': stat, 'price_peak_var': stat})
print(price_stat.head())
# Out:
#                                       id  price_off_peak_var  price_peak_var  \
# 0       038af19179925da21a25619c5a24b745            0.151367        0.000000
# 1       038af19179925da21a25619c5a24b745            0.151367        0.000000
# 2       038af19179925da21a25619c5a24b745            0.151367        0.000000
# 3       038af19179925da21a25619c5a24b745            0.149626        0.000000
# 4       038af19179925da21a25619c5a24b745            0.149626        0.000000
# ...                                  ...                 ...             ...
# 192990  16f51cdc2baa19af0b940ee1b3dd17d5            0.129444        0.106863
# 192991  16f51cdc2baa19af0b940ee1b3dd17d5            0.129444        0.106863
# 192992  16f51cdc2baa19af0b940ee1b3dd17d5            0.129444        0.106863
# 192993  16f51cdc2baa19af0b940ee1b3dd17d5            0.129444        0.106863
# 192994  16f51cdc2baa19af0b940ee1b3dd17d5            0.129444        0.106863
#
# ...

# %%
price_churn_df =  pd.merge(price_stat, churn, left_on="id", right_on="Companies", how="left")
print(price_churn_df.head())
# Out:
#    (price_off_peak_var, max)  (price_off_peak_var, min)  \
# 0                   0.128067                   0.119906
# 1                   0.148405                   0.143943
# 2                   0.205742                   0.150837
# 3                   0.123086                   0.113068
# 4                   0.149902                   0.145440
#
#    (price_off_peak_var, mean)  (price_off_peak_fix, max)  \
# 0                    0.124338                  40.728885
# 1                    0.146426                  44.444710
# 2                    0.181558                  45.944710
# 3                    0.118757                  40.728885
# 4                    0.147926                  44.266931
#
#    (price_off_peak_fix, min)  (price_off_peak_fix, mean)  \
# 0                  40.565969                   40.701732
# 1                  44.266931                   44.385450
# 2                  44.444710                   45.319710
# ...

# %%
#let see what kind of correlations these values have with churn
corr = price_churn_df.corr()[['churn']].sort_values(by='churn', ascending=False)
sns.heatmap(corr, annot=True)

# %% [markdown]
# From correlations we can see that there are higher possibility for churn in price peak times. Also max values have slightly higher correlation than min values, which also favour that customers are slightly price sensitive.

# %%
sns.barplot(data)

# %%
#merge churn df with price df


price_churn_df = pd.merge(price_df, churn, left_on="id", right_on="Companies", how="right")
print(price_churn_df.head())
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  2015-01-01            0.125976
# 1  24011ae4ebbe3035111d65fa7c15bc57  2015-02-01            0.125976
# 2  24011ae4ebbe3035111d65fa7c15bc57  2015-03-01            0.125976
# 3  24011ae4ebbe3035111d65fa7c15bc57  2015-04-01            0.125976
# 4  24011ae4ebbe3035111d65fa7c15bc57  2015-05-01            0.125976
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0        0.103395            0.071536           40.565969       24.339581
# 1        0.103395            0.071536           40.565969       24.339581
# 2        0.103395            0.071536           40.565973       24.339578
# 3        0.103395            0.071536           40.565973       24.339578
# 4        0.103395            0.071536           40.565973       24.339578
#
#    price_mid_peak_fix                         Companies  churn
# ...

# %%
corr = price_churn_df.corr(method="pearson")[['churn']].sort_values(by='churn', ascending=False)

sns.heatmap(corr, annot=True)

# %% [markdown]
# Prepare a half-page summary or slide of key findings and add some suggestions for data augmentation – which other sources of data should the client provide you with and which open source datasets might be useful? You should spend 10-15 minutes on this.
#
# For your final deliverable, please submit your analysis (in the form of a jupyter notebook, code script or PDF) as well as your half-page summary document.

# %% [markdown]
# **Key Findings**
#
# 1. About 9.7% of customers changed providers
#
# 2. Customers are most likely to change the provider in second year of contract
#
# 3. Changes in prices affect to customer churn slightly, but there even in these analysis, we have notice more significant factors.
#
# 4. Some selling channels are way more likely to customer churn than others
#
# **Suggestions**
#
# 1. Would be useful to have data especially about those customer, who have changed the company.
#
# 2. Would be nice to have some data about the selling channel to clarify, why some increase the customer churn
#
# 3. Data about customer service and other customer factors would also usefull to analyse to see reasons for customer churn
